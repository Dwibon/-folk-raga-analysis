# %%
import os
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

PROJECT_ROOT = "/Users/dwibon/Desktop/IKS-Internship"
os.chdir(PROJECT_ROOT)

FEATURES_PATH = "dataset_segments/segment_features.csv"
RANDOM_STATE = 42

# %%
df = pd.read_csv(FEATURES_PATH)

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nGenre distribution:\n", df["genre"].value_counts())
print("\nSegments per singer (top 10):\n", df["singer"].value_counts().head(10))
df.head()
# Out:
# Shape: (3088, 79)
#
# Columns: ['Recoding ID', 'genre', 'subgenre', 'Song Title', 'singer', 'Gender', 'YouTube URL', 'duration_sec', 'segment_id', 'recording_id', 'segment_index', 'segment_start_sec', 'segment_end_sec', 'segment_duration_sec', 'edge_trimmed', 'rms_energy', 'likely_silent', 'segment_filepath', 'time_rms_mean', 'time_rms_std', 'time_zcr_mean', 'time_zcr_std', 'spectral_centroid_mean', 'spectral_centroid_std', 'spectral_rolloff_mean', 'spectral_rolloff_std', 'spectral_bandwidth_mean', 'spectral_bandwidth_std', 'mfcc_1_mean', 'mfcc_1_std', 'mfcc_2_mean', 'mfcc_2_std', 'mfcc_3_mean', 'mfcc_3_std', 'mfcc_4_mean', 'mfcc_4_std', 'mfcc_5_mean', 'mfcc_5_std', 'mfcc_6_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std', 'mfcc_8_mean', 'mfcc_8_std', 'mfcc_9_mean', 'mfcc_9_std', 'mfcc_10_mean', 'mfcc_10_std', 'mfcc_11_mean', 'mfcc_11_std', 'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean', 'mfcc_13_std', 'chroma_1_mean', 'chroma_1_std', 'chroma_2_mean', 'chroma_2_std', 'chroma_3_mean', 'chroma_3_std', 'chroma_4_mean', 'chroma_4_std', 'chroma_5_mean', 'chroma_5_std', 'chroma_6_mean', 'chroma_6_std', 'chroma_7_mean', 'chroma_7_std', 'chroma_8_mean', 'chroma_8_std', 'chroma_9_mean', 'chroma_9_std', 'chroma_10_mean', 'chroma_10_std', 'chroma_11_mean', 'chroma_11_std', 'chroma_12_mean', 'chroma_12_std', 'tempo_bpm']
#
# Genre distribution:
#  genre
# Kamrupi       1592
# Goalpariya    1496
# Name: count, dtype: int64
#
# Segments per singer (top 10):
#  singer
# Pratima Pandey Barua     603
# Rameshwar Pathak         483
# Abdul Jabbar             343
# Zubeen Garg              186
# Manik Ali                129
# Parag Talukdar           127
# Pranita Baishya          124
# Archana Baruah           106
# Jumi Das                  93
# Bina sharma               88
# Name: count, dtype: int64
#    Recoding ID    genre  subgenre        Song Title            singer Gender  \
# 0  AFM0001.wav  Kamrupi       NaN  Pokhi Roya Ja Re  Rameshwar Pathak      M
# 1  AFM0001.wav  Kamrupi       NaN  Pokhi Roya Ja Re  Rameshwar Pathak      M
# 2  AFM0001.wav  Kamrupi       NaN  Pokhi Roya Ja Re  Rameshwar Pathak      M
# 3  AFM0001.wav  Kamrupi       NaN  Pokhi Roya Ja Re  Rameshwar Pathak      M
# 4  AFM0001.wav  Kamrupi       NaN  Pokhi Roya Ja Re  Rameshwar Pathak      M
#
#                                         YouTube URL  duration_sec  \
# 0  https://youtu.be/dU8AHeKOUQE?si=y9zCEIdga78WbKFz         261.0
# 1  https://youtu.be/dU8AHeKOUQE?si=y9zCEIdga78WbKFz         261.0
# 2  https://youtu.be/dU8AHeKOUQE?si=y9zCEIdga78WbKFz         261.0
# 3  https://youtu.be/dU8AHeKOUQE?si=y9zCEIdga78WbKFz         261.0
# 4  https://youtu.be/dU8AHeKOUQE?si=y9zCEIdga78WbKFz         261.0
#
#       segment_id recording_id  ...  chroma_8_std  chroma_9_mean  chroma_9_std  \
# 0  AFM0001_seg00  AFM0001.wav  ...      0.439755       0.166030      0.170797
# 1  AFM0001_seg01  AFM0001.wav  ...      0.447027       0.117371      0.161500
# 2  AFM0001_seg02  AFM0001.wav  ...      0.419215       0.248990      0.288506
# 3  AFM0001_seg03  AFM0001.wav  ...      0.380009       0.229324      0.273638
# 4  AFM0001_seg04  AFM0001.wav  ...      0.372806       0.248047      0.274497
#
#    chroma_10_mean  chroma_10_std  chroma_11_mean  chroma_11_std  \
# 0        0.332119       0.421232        0.082138       0.122629
# 1        0.113279       0.226125        0.034327       0.102987
# 2        0.360282       0.420630        0.097940       0.156430
# 3        0.478196       0.442659        0.340631       0.362398
# 4        0.391146       0.383597        0.256250       0.290637
#
#   chroma_12_mean  chroma_12_std   tempo_bpm
# 0       0.023384       0.042176  117.453835
# 1       0.028805       0.066027  143.554688
# 2       0.028626       0.063558   92.285156
# 3       0.093773       0.188723  129.199219
# 4       0.143844       0.228356   92.285156
#
# [5 rows x 79 columns]

# %%
GROUP_PREFIXES = {
    "time": "time_",
    "spectral": "spectral_",
    "mfcc": "mfcc_",
    "chroma": "chroma_",
    "tempo": "tempo_",
}

# CHANGE THIS to test a different group - rerun from here down
FEATURE_GROUPS_TO_TEST = ["tempo"]

def select_feature_columns(df, groups):
    cols = []
    for g in groups:
        prefix = GROUP_PREFIXES[g]
        cols.extend([c for c in df.columns if c.startswith(prefix)])
    if not cols:
        raise ValueError(f"No columns found for groups {groups}")
    return cols

cols = select_feature_columns(df, FEATURE_GROUPS_TO_TEST)
print(f"Testing: {FEATURE_GROUPS_TO_TEST}  ({len(cols)} features)")
print(cols)

X = df[cols].values
y = df["genre"].values
singers = df["singer"].values
# Out:
# Testing: ['tempo']  (1 features)
# ['tempo_bpm']

# %%
def loso_per_singer(X, y, singers, model, model_name):
    unique_singers = np.unique(singers)
    scaler = StandardScaler()
    results = []

    for singer in unique_singers:
        test_mask = singers == singer
        train_mask = ~test_mask
        if test_mask.sum() == 0 or train_mask.sum() == 0:
            continue

        X_train = scaler.fit_transform(X[train_mask])
        X_test = scaler.transform(X[test_mask])

        model.fit(X_train, y[train_mask])
        preds = model.predict(X_test)
        acc = accuracy_score(y[test_mask], preds)

        results.append({
            "singer": singer,
            "n_segments": test_mask.sum(),
            "accuracy": round(acc, 3),
            "genre": y[test_mask][0],  # each singer's segments share one genre
        })

    return pd.DataFrame(results).sort_values("n_segments", ascending=False)

svm = SVC(kernel="rbf", C=1.0, gamma="scale", random_state=RANDOM_STATE)
per_singer_df = loso_per_singer(X, y, singers, svm, "SVM")
per_singer_df
# Out:
#                                  singer  n_segments  accuracy       genre
# 18                Pratima Pandey Barua          603     0.317  Goalpariya
# 23                     Rameshwar Pathak         483     0.516     Kamrupi
# 0                          Abdul Jabbar         343     0.860  Goalpariya
# 31                          Zubeen Garg         186     0.704     Kamrupi
# 13                            Manik Ali         129     0.752  Goalpariya
# 16                       Parag Talukdar         127     0.717     Kamrupi
# 17                      Pranita Baishya         124     0.992     Kamrupi
# 5                        Archana Baruah         106     0.698     Kamrupi
# 11                             Jumi Das          93     0.978     Kamrupi
# 8                           Bina sharma          88     0.841     Kamrupi
# 27                            Sumi Deka          82     0.854     Kamrupi
# 28                            Suren Das          74     0.905     Kamrupi
# 14                Manik Ali, Anita Saha          62     0.774  Goalpariya
# 25        Rameshwar Pathak, Zubeen garg          43     0.721     Kamrupi
# 1                Abdul Jabbar and group          42     0.548  Goalpariya
# 9                        Dhanada Pathak          38     0.632     Kamrupi
# 19                      Rahima K. Begum          36     1.000  Goalpariya
# 21           Rahima K. Begum, Manik Ali          35     1.000  Goalpariya
# 3                         Akshay Barman          34     0.088     Kamrupi
# 29                           Ujjwal Roy          33     0.879     Kamrupi
# 2        Abdul Jabbar, Prasenjit Sarkar          32     0.969  Goalpariya
# 12                            Kamal Das          30     1.000     Kamrupi
# 26                       Shandhya menon          30     0.733     Kamrupi
# 15                        Meherun Nessa          28     0.750  Goalpariya
# 24     Rameshwar Pathak, Dhanada Pathak          28     0.357     Kamrupi
# 20  Rahima K. Begum, Krishnamoni Chetia          27     0.778  Goalpariya
# 22      Rahima K. Begum, Shohidul Hoque          27     0.889  Goalpariya
# 10                      Dhanmoni Saikia          26     0.615     Kamrupi
# 7      Bina Das Borthakur, Dikshu Sarma          26     1.000  Goalpariya
# 4                            Anita Saha          26     0.038  Goalpariya
# 30                              Unknown          25     0.720     Kamrupi
# 6                    Bina Das Borthakur          22     0.455  Goalpariya

# %%
MIN_SEGMENTS = 10  # adjust based on your actual segment counts per singer

reliable = per_singer_df[per_singer_df["n_segments"] >= MIN_SEGMENTS].copy()

print(f"Singers with >= {MIN_SEGMENTS} segments: {len(reliable)} of {len(per_singer_df)} total\n")
print("Sorted worst to best (these are the ones that matter most):")
reliable.sort_values("accuracy")
# Out:
# Singers with >= 10 segments: 32 of 32 total
#
# Sorted worst to best (these are the ones that matter most):
#                                  singer  n_segments  accuracy       genre
# 4                            Anita Saha          26     0.038  Goalpariya
# 3                         Akshay Barman          34     0.088     Kamrupi
# 18                Pratima Pandey Barua          603     0.317  Goalpariya
# 24     Rameshwar Pathak, Dhanada Pathak          28     0.357     Kamrupi
# 6                    Bina Das Borthakur          22     0.455  Goalpariya
# 23                     Rameshwar Pathak         483     0.516     Kamrupi
# 1                Abdul Jabbar and group          42     0.548  Goalpariya
# 10                      Dhanmoni Saikia          26     0.615     Kamrupi
# 9                        Dhanada Pathak          38     0.632     Kamrupi
# 5                        Archana Baruah         106     0.698     Kamrupi
# 31                          Zubeen Garg         186     0.704     Kamrupi
# 16                       Parag Talukdar         127     0.717     Kamrupi
# 30                              Unknown          25     0.720     Kamrupi
# 25        Rameshwar Pathak, Zubeen garg          43     0.721     Kamrupi
# 26                       Shandhya menon          30     0.733     Kamrupi
# 15                        Meherun Nessa          28     0.750  Goalpariya
# 13                            Manik Ali         129     0.752  Goalpariya
# 14                Manik Ali, Anita Saha          62     0.774  Goalpariya
# 20  Rahima K. Begum, Krishnamoni Chetia          27     0.778  Goalpariya
# 8                           Bina sharma          88     0.841     Kamrupi
# 27                            Sumi Deka          82     0.854     Kamrupi
# 0                          Abdul Jabbar         343     0.860  Goalpariya
# 29                           Ujjwal Roy          33     0.879     Kamrupi
# 22      Rahima K. Begum, Shohidul Hoque          27     0.889  Goalpariya
# 28                            Suren Das          74     0.905     Kamrupi
# 2        Abdul Jabbar, Prasenjit Sarkar          32     0.969  Goalpariya
# 11                             Jumi Das          93     0.978     Kamrupi
# 17                      Pranita Baishya         124     0.992     Kamrupi
# 21           Rahima K. Begum, Manik Ali          35     1.000  Goalpariya
# 19                      Rahima K. Begum          36     1.000  Goalpariya
# 7      Bina Das Borthakur, Dikshu Sarma          26     1.000  Goalpariya
# 12                            Kamal Das          30     1.000     Kamrupi

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5))
colors = ["#d62728" if g == "Kamrupi" else "#1f77b4" for g in reliable.sort_values("accuracy")["genre"]]
ax.barh(reliable.sort_values("accuracy")["singer"], reliable.sort_values("accuracy")["accuracy"], color=colors)
ax.axvline(0.5, color="gray", linestyle="--", label="Chance level")
ax.set_xlabel("Accuracy")
ax.set_title("Per-Singer Accuracy - Tempo Feature (singers with >= {} segments)".format(MIN_SEGMENTS))
ax.legend()
plt.tight_layout()
plt.savefig("results/per_singer_tempo.png", dpi=150)
plt.show()

# %%
# ==========================================
# FEATURE SELECTION - TEMPO + MFCC
# ==========================================

FEATURE_GROUPS_TO_TEST = ["tempo", "mfcc"]

cols = select_feature_columns(df, FEATURE_GROUPS_TO_TEST)

X = df[cols].values
y = df["genre"].values
singers = df["singer"].values

feature_names = cols

print(feature_names)
print("Total features:", len(feature_names))
# Out:
# ['tempo_bpm', 'mfcc_1_mean', 'mfcc_1_std', 'mfcc_2_mean', 'mfcc_2_std', 'mfcc_3_mean', 'mfcc_3_std', 'mfcc_4_mean', 'mfcc_4_std', 'mfcc_5_mean', 'mfcc_5_std', 'mfcc_6_mean', 'mfcc_6_std', 'mfcc_7_mean', 'mfcc_7_std', 'mfcc_8_mean', 'mfcc_8_std', 'mfcc_9_mean', 'mfcc_9_std', 'mfcc_10_mean', 'mfcc_10_std', 'mfcc_11_mean', 'mfcc_11_std', 'mfcc_12_mean', 'mfcc_12_std', 'mfcc_13_mean', 'mfcc_13_std']
# Total features: 27

# %%
from sklearn.ensemble import RandomForestClassifier

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

rf = RandomForestClassifier(
    n_estimators=500,
    random_state=42
)

rf.fit(X_scaled, y)

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": rf.feature_importances_
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df
# Out:
#          Feature  Importance
# 0      tempo_bpm    0.108038
# 9    mfcc_5_mean    0.069103
# 5    mfcc_3_mean    0.059917
# 15   mfcc_8_mean    0.056224
# 7    mfcc_4_mean    0.054930
# 1    mfcc_1_mean    0.048648
# 23  mfcc_12_mean    0.046327
# 26   mfcc_13_std    0.045222
# 13   mfcc_7_mean    0.043477
# 17   mfcc_9_mean    0.041946
# 25  mfcc_13_mean    0.041497
# 3    mfcc_2_mean    0.038736
# 10    mfcc_5_std    0.037748
# 19  mfcc_10_mean    0.036648
# 21  mfcc_11_mean    0.036368
# 11   mfcc_6_mean    0.032546
# 24   mfcc_12_std    0.029919
# 4     mfcc_2_std    0.025389
# 14    mfcc_7_std    0.020253
# 16    mfcc_8_std    0.020155
# 12    mfcc_6_std    0.018801
# 20   mfcc_10_std    0.017794
# 22   mfcc_11_std    0.016625
# 6     mfcc_3_std    0.014671
# 2     mfcc_1_std    0.014379
# 18    mfcc_9_std    0.012949
# 8     mfcc_4_std    0.011692

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.barh(
    importance_df["Feature"],
    importance_df["Importance"]
)

plt.gca().invert_yaxis()

plt.title("Random Forest Feature Importance")

plt.xlabel("Importance")

plt.show()

# %%
def loso_accuracy(X, y, singers):

    unique_singers = np.unique(singers)

    scaler = StandardScaler()

    y_true = []
    y_pred = []

    for singer in unique_singers:

        test_mask = singers == singer
        train_mask = ~test_mask

        X_train = scaler.fit_transform(X[train_mask])
        X_test = scaler.transform(X[test_mask])

        model = SVC(
            kernel="rbf",
            C=1.0,
            gamma="scale",
            random_state=42
        )

        model.fit(X_train, y[train_mask])

        pred = model.predict(X_test)

        y_true.extend(y[test_mask])
        y_pred.extend(pred)

    return accuracy_score(y_true, y_pred)

# %%
results = []

ranked_features = importance_df["Feature"].tolist()

for k in [3,5,7,10,12,15,18,20,25,27]:

    top_features = ranked_features[:k]

    idx = [
        feature_names.index(f)
        for f in top_features
    ]

    X_top = X[:, idx]

    acc = loso_accuracy(
        X_top,
        y,
        singers
    )

    results.append({
        "Top Features": k,
        "Accuracy": acc
    })

results_df = pd.DataFrame(results)

results_df
# Out:
#    Top Features  Accuracy
# 0             3  0.597474
# 1             5  0.703692
# 2             7  0.672927
# 3            10  0.674223
# 4            12  0.709197
# 5            15  0.707902
# 6            18  0.694301
# 7            20  0.699806
# 8            25  0.698834
# 9            27  0.693653

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results_df["Top Features"],
    results_df["Accuracy"],
    marker="o"
)

plt.grid(True)

plt.xlabel("Number of Features")

plt.ylabel("LOSO Accuracy")

plt.title("Feature Selection")

plt.show()

# %%
best_row = results_df.loc[
    results_df["Accuracy"].idxmax()
]

best_k = best_row["Top Features"]

best_features = ranked_features[:int(best_k)]

print("Best k:", best_k)

print()

print("Selected Features:")

for f in best_features:
    print(f)
# Out:
# Best k: 12.0
#
# Selected Features:
# tempo_bpm
# mfcc_5_mean
# mfcc_3_mean
# mfcc_8_mean
# mfcc_4_mean
# mfcc_1_mean
# mfcc_12_mean
# mfcc_13_std
# mfcc_7_mean
# mfcc_9_mean
# mfcc_13_mean
# mfcc_2_mean
